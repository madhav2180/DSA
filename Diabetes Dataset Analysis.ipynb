# %%
import numpy as np
import pandas as pd
df = pd.read_csv('diabetes_model.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
#Univariate Analysis

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('diabetes_model.csv')
plt.hist(df[df['Outcome']==0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %%
#Bivariate Analysis

# %%
import seaborn as sns
sns.scatterplot(x='Glucose',y='Insulin',data=df)
plt.show()

# %%
corr_matrix = df.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.137245       0.165089      -0.101968
# Glucose                      0.137245  1.000000       0.151446       0.073133
# BloodPressure                0.165089  0.151446       1.000000       0.209564
# SkinThickness               -0.101968  0.073133       0.209564       1.000000
# Insulin                     -0.083955  0.320291       0.083704       0.433628
# BMI                         -0.005699  0.237282       0.283813       0.379994
# DiabetesPedigreeFunction    -0.039171  0.134167       0.025739       0.180571
# Age                          0.552744  0.251873       0.227663      -0.111832
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.083955 -0.005699                 -0.039171
# Glucose                   0.320291  0.237282                  0.134167
# ...

# %%
a = df['Age'].values
b = df['BloodPressure'].values
plt.hist(a,bins=10,color='green')
plt.hist(b,bins=10,color='red',alpha=0.3)
plt.xlabel('insulin')
plt.ylabel('glucose')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Multivariate Analysis

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection="3d")
x=df['Pregnancies'].values
y=df['Age'].values
z=df['BloodPressure'].values
ax.plot3D(x, y, z, 'red')

# %%
sns.pairplot(data=df,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue = 'Outcome')
plt.show()
